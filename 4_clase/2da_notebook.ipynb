# %%
"Hola mundo "
# Out:
# 'Hola mundo '

# %%
#Función 'input'

numero= input("Hey, introduce un número")

# %%
numero
# Out:
# '10'

# %%
numero= float(numero)
numero
# Out:
# 10.0

# %%
numero= int(numero)
numero
# Out:
# 10

# %%
float("10.5")
# Out:
# 10.5
