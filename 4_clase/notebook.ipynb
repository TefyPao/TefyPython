# %%
##Creando errores
# Out:
# Hola mundo

# %%
## ¿Cómo controlar errores? 
## "try catch" para corregir errores

try: ##abre un contexto 
    number= 1
    string="Hola"
    result = number + string 
except: ##abre otro contexto,
        ## intenta todo lo anterior y si hay una excepción, abre un nuevo contexto
    print("Hay un error")
# Out:
# Hay un error

# %%
number= 1
string="Hola" 
result = number + string
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 3
#       1 number= 1
#       2 string="Hola"
# ----> 3 result = number + string
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
try: ##abre un contexto 
    number= 1
    string="Hola"
    result = string + string 
    var= string[10]
except TypeError as var2: ##abre otro contexto,
    print(var2)
        ## intenta todo lo anterior y si hay una excepción, abre un nuevo contexto
    print("Hay un error de type error")
except IndexError as var2:
    print(var2)
    print("Hay un error de index")
except:
    print("Hay un error genérico")
# Out:
# string index out of range
# Hay un error de index

# %%
number= 1
string="Hola"
result = string + string 
var= string[10]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[13], line 4
#       2 string="Hola"
#       3 result = string + string
# ----> 4 var= string[10]
#
# IndexError: string index out of range

# %%
try: ##abre un contexto 
    number= 1
    string="Hola"
    result = number + string 
    var= string[10]
except Exception as error: ##todo error en python es generado por Exception
    print(error)
    print("Hay un error genérico")
# Out:
# unsupported operand type(s) for +: 'int' and 'str'
# Hay un error genérico

# %%
try: 
    10/0
except:
    raise ValueError("División por cero no se puede") ## para lanzar el error
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[25], line 2
#       1 try:
# ----> 2     10/0
#       3 except:
#
# ZeroDivisionError: division by zero
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[25], line 4
#       2     10/0
#       3 except:
# ----> 4     raise ValueError("División por cero no se puede") ## para lanzar el error
#
# ValueError: División por cero no se puede

# %%
## Control de errores: condicionales
##sintaxis: if (comparación): (las comparaciones son operaciones o algo cuyo resultado es un booleano)
comp= 1 > 0
comp2= 0 > 0

#caso 1
if (comp):
    print("cuando comp es True")
#------------------------------------------

#caso 2
if (comp):
    print ("cuando comp es True")
else: 
    print("cuando comp es False")
#------------------------------------------

#caso 3
if (comp):
    print("cuando comp es True")
elif (comp and comp2):
    print("otra condición pero negando la de arriba")
else: #opcional
    print("Ninguna es True")
#------------------------------------------

#caso 4
if (comp):
    print ("cuando comp es True")
    if (comp2):
        print ("cuando comp y comp2 son true")

#------------------------------------------
#caso 5
if (comp and comp2):
    print("cuando comp y comp2 son True")
# Out:
# cuando comp es True
# cuando comp es True
# cuando comp es True
# cuando comp es True

# %%
#Funciones 

#Una función puede retornar varios parámetros
def nombre_funcion(a, b, c):
    return a+b, a+c, b+c, "Hola"

# %%
var= nombre_funcion(3, 4, 5)
print(var[0])
print(var[1])
print(var[2])
nombre_funcion(var[0], var[1], var[2])
##imprime una tupla, las cuales son inmutables. No se le puede agregar elementos, modificar elementos
##Las tuplas pueden ser indexadas, empezando por el índice cero
# Out:
# 7
# 8
# 9
# (15, 16, 17, 'Hola')

# %%
var[-1], var[-2], var[-3], var[-4]
# Out:
# ('Hola', 9, 8, 7)

# %%
tupla_variable= ("Hola", 2, 3, 1.5, 0xb)
tupla_variable
# Out:
# ('Hola', 2, 3, 1.5, 11)

# %%
tupla_variable[0]= "chao"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[46], line 1
# ----> 1 tupla_variable[0]= "chao"
#
# TypeError: 'tuple' object does not support item assignment

# %%
##slicing tuplas
tupla_variable[1:3]
# Out:
# (2, 3)

# %%
try: 
    print("Welcome to Tefy's calculator")
    print("A continuación, ingresa dos números y elige la operación del menú de opciones:")
    print("Menú de opciones:")
    print("1. Suma")
    print("2. Resta")
    print("3. Multiplicación")
    print("4. División")
    print("5. Potenciación")
    print("6. Módulo")
    x= int(input("Introduce el primer número"))
    y= int(input("Introduce el 2do número"))
    operation= input("¿Qué operación deseas hacer?: (Selecciona una opción del anterior menú de opciones)")
    

    if operation =="1":
        print("La suma de los dos números es:", x + y)
    elif operation=="2":
        print("El resultado de restar los dos números es:", x - y)
    elif operation== "3":
        print("El producto de los dos números es:", x ** y)
    elif operation== "4":
        print("El cociente de dividir los dos números es:", x / y)   
    elif operation== "5":
        print("La potencia es:", x ** y)    
    elif operation=="6":
        print("El módulo entre los dos números es:", x % y)
    else:
        print("Operación no válida.")

except ValueError:
    print("Hay un error. No se pueden operar números con letras")

except: 
    print("División por cero no es posible")
# Out:
# Welcome to Tefy's calculator
# A continuación, ingresa dos números y elige la operación del menú de opciones:
# Menú de opciones:
# 1. Suma
# 2. Resta
# 3. Multiplicación
# 4. División
# 5. Potenciación
# 6. Módulo
# Hay un error. No se pueden operar números con letras
