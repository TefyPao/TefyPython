# %%
print("Hola mundo")
# Out:
# Hola mundo

# %%
12.1, type(12.1)
# Out:
# (12.1, float)

# %%
True and False, True and True, False and True, False and False
# Out:
# (False, True, False, False)

# %%
True or False, True or True, False or True, False or False
# Out:
# (True, True, True, False)

# %%
not True, not False
# Out:
# (False, True)

# %%
tefy= "Estefanny"
type(tefy)
# Out:
# str

# %%
var1= 2
var2= 5
sum = var1 + var2
res = var1 - var2
mult= var1 * var2 
div = var1 / var2
print (sum, res, mult, div)
# Out:
# 7 -3 10 0.4

# %% [markdown]
# # Operación módulo
# ## Devuelve residuo de la división entre dos números
# módulo: %

# %%
4 % 2
2 % 4
# Out:
# 2
